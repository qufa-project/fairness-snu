# %% [markdown]
# # 필요 Library 설치

# %%
# !pip install pandas 
# !pip install numpy
# !pip install scikit-learn 
# !pip install umap-learn 
# !pip install matplotlib
# !pip install seaborn
# Out:
# Requirement already satisfied: pandas in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from pandas) (1.21.2)
# Requirement already satisfied: pytz>=2017.3 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from pandas) (2021.1)
# Requirement already satisfied: six>=1.5 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/iskim/.pyenv/versions/3.9.4/bin/python3.9 -m pip install --upgrade pip' command.
# Requirement already satisfied: numpy in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (1.21.2)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/iskim/.pyenv/versions/3.9.4/bin/python3.9 -m pip install --upgrade pip' command.
# Requirement already satisfied: scikit-learn in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (0.24.2)
# Requirement already satisfied: numpy>=1.13.3 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from scikit-learn) (1.21.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from scikit-learn) (1.0.1)
# Requirement already satisfied: scipy>=0.19.1 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from scikit-learn) (1.7.1)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/iskim/.pyenv/versions/3.9.4/bin/python3.9 -m pip install --upgrade pip' command.
# Collecting umap-learn
#   Downloading umap-learn-0.5.1.tar.gz (80 kB)
#      |████████████████████████████████| 80 kB 2.7 MB/s eta 0:00:011
# Requirement already satisfied: numpy>=1.17 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from umap-learn) (1.21.2)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from umap-learn) (0.24.2)
# Requirement already satisfied: scipy>=1.0 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from umap-learn) (1.7.1)
# Collecting numba>=0.49
#   Downloading numba-0.54.1-cp39-cp39-macosx_10_14_x86_64.whl (2.3 MB)
#      |████████████████████████████████| 2.3 MB 19.1 MB/s eta 0:00:01
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.4.tar.gz (1.1 MB)
#      |████████████████████████████████| 1.1 MB 31.1 MB/s eta 0:00:01
# Collecting llvmlite<0.38,>=0.37.0rc1
#   Downloading llvmlite-0.37.0-cp39-cp39-macosx_10_9_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 79.1 MB/s eta 0:00:01
# Requirement already satisfied: setuptools in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from numba>=0.49->umap-learn) (49.2.1)
# Collecting numpy>=1.17
#   Using cached numpy-1.20.3-cp39-cp39-macosx_10_9_x86_64.whl (16.1 MB)
# Requirement already satisfied: joblib>=0.11 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from pynndescent>=0.5->umap-learn) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from scikit-learn>=0.22->umap-learn) (2.2.0)
# Using legacy 'setup.py install' for umap-learn, since package 'wheel' is not installed.
# Using legacy 'setup.py install' for pynndescent, since package 'wheel' is not installed.
# Installing collected packages: numpy, llvmlite, numba, pynndescent, umap-learn
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.2
#     Uninstalling numpy-1.21.2:
#       Successfully uninstalled numpy-1.21.2
#     Running setup.py install for pynndescent ... done
#     Running setup.py install for umap-learn ... done
# Successfully installed llvmlite-0.37.0 numba-0.54.1 numpy-1.20.3 pynndescent-0.5.4 umap-learn-0.5.1
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/iskim/.pyenv/versions/3.9.4/bin/python3.9 -m pip install --upgrade pip' command.
# Requirement already satisfied: matplotlib in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (3.4.3)
# Requirement already satisfied: numpy>=1.16 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib) (1.20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from cycler>=0.10->matplotlib) (1.16.0)
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/iskim/.pyenv/versions/3.9.4/bin/python3.9 -m pip install --upgrade pip' command.
# Collecting seaborn
#   Using cached seaborn-0.11.2-py3-none-any.whl (292 kB)
# Requirement already satisfied: pandas>=0.23 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from seaborn) (1.3.2)
# Requirement already satisfied: matplotlib>=2.2 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from seaborn) (3.4.3)
# Requirement already satisfied: numpy>=1.15 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from seaborn) (1.20.3)
# Requirement already satisfied: scipy>=1.0 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from seaborn) (1.7.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (8.3.1)
# Requirement already satisfied: cycler>=0.10 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from matplotlib>=2.2->seaborn) (2.4.7)
# Requirement already satisfied: six in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages (from pandas>=0.23->seaborn) (2021.1)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.11.2
# WARNING: You are using pip version 21.2.4; however, version 21.3 is available.
# You should consider upgrading via the '/Users/iskim/.pyenv/versions/3.9.4/bin/python3.9 -m pip install --upgrade pip' command.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from sklearn.manifold import TSNE
import umap.umap_ as umap
# Out:
# ---------------------------------------------------------------------------
# ContextualVersionConflict                 Traceback (most recent call last)
# /var/folders/hh/n08dz9z16kq2w0xnww9w00fh0000gn/T/ipykernel_10166/1932931973.py in <module>
#       5 from sklearn.impute import SimpleImputer
#       6 from sklearn.manifold import TSNE
# ----> 7 import umap.umap_ as umap
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/umap/__init__.py in <module>
#       1 from warnings import warn, catch_warnings, simplefilter
# ----> 2 from .umap_ import UMAP
#       3
#       4 try:
#       5     with catch_warnings():
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/umap/umap_.py in <module>
#      45 )
#      46
# ---> 47 from pynndescent import NNDescent
#      48 from pynndescent.distances import named_distances as pynn_named_distances
#      49 from pynndescent.sparse import sparse_named_distances as pynn_sparse_named_distances
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pynndescent/__init__.py in <module>
#      13         numba.config.THREADING_LAYER = "workqueue"
#      14
# ---> 15 __version__ = pkg_resources.get_distribution("pynndescent").version
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pkg_resources/__init__.py in get_distribution(dist)
#     478         dist = Requirement.parse(dist)
#     479     if isinstance(dist, Requirement):
# --> 480         dist = get_provider(dist)
#     481     if not isinstance(dist, Distribution):
#     482         raise TypeError("Expected string, Requirement, or Distribution", dist)
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pkg_resources/__init__.py in get_provider(moduleOrReq)
#     354     """Return an IResourceProvider for the named module or requirement"""
#     355     if isinstance(moduleOrReq, Requirement):
# --> 356         return working_set.find(moduleOrReq) or require(str(moduleOrReq))[0]
#     357     try:
#     358         module = sys.modules[moduleOrReq]
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pkg_resources/__init__.py in require(self, *requirements)
#     897         included, even if they were already activated in this working set.
#     898         """
# --> 899         needed = self.resolve(parse_requirements(requirements))
#     900
#     901         for dist in needed:
#
# ~/.pyenv/versions/3.9.4/lib/python3.9/site-packages/pkg_resources/__init__.py in resolve(self, requirements, env, installer, replace_conflicting, extras)
#     788                 # Oops, the "best" so far conflicts with a dependency
#     789                 dependent_req = required_by[req]
# --> 790                 raise VersionConflict(dist, req).with_context(dependent_req)
#     791
#     792             # push the new requirements onto the stack
#
# ContextualVersionConflict: (numpy 1.21.2 (/Users/iskim/.pyenv/versions/3.9.4/lib/python3.9/site-packages), Requirement.parse('numpy<1.21,>=1.17'), {'numba'})

# %% [markdown]
# # 데이터 Description

# %% [markdown]
# - 'generated_imputed.csv` : 생성된 자료 중 일부 결측값을 해당 컬럼의 평균값으로 대치하여 만든 데이터

# %%
generated_imputed = pd.read_csv("generated_imputed.csv", engine="python")

# %%
# 데이터 확인
generated_imputed.head()
# Out:
#    WBC  fschizoyn  Weight  fbipolyn  dep  flipyn    FBS  asth2  FEF25_75__exp  \
# 0  6.6        1.0    64.4       1.0  1.0     1.0   86.0    1.0     132.000000
# 1  4.2        1.0    69.6       1.0  1.0     1.0  110.0    1.0      66.000000
# 2  9.6        1.0    43.8       1.0  1.0     1.0  123.0    1.0      35.000000
# 3  8.2        1.0    66.3       1.0  1.0     1.0  120.0    1.0      93.520318
# 4  5.4        1.0    77.7       1.0  1.0     1.0  105.0    2.0      93.520318
#
#    htn  ...  Calcium    PEF__exp   DBP    FVC__exp  jb_irelay  ces_dep  sex  \
# 0  2.0  ...     10.8   80.000000  65.0   90.000000        1.0     25.0  2.0
# 1  1.0  ...      8.8  120.000000  82.0  100.000000        1.0      9.0  2.0
# 2  1.0  ...     10.3   55.000000  82.0  119.000000        1.0     19.0  2.0
# 3  1.0  ...     10.0  105.912085  79.0   98.557767        1.0     11.0  1.0
# 4  1.0  ...      9.2  105.912085  76.0   98.557767        1.0     20.0  1.0
#
#         PEF  alch   AST
# 0  6.200000   1.0  10.0
# 1  6.200000   1.0  12.0
# 2  8.400000   1.0  22.0
# 3  7.310154   1.0  25.0
# 4  7.310154   1.0  47.0
#
# [5 rows x 68 columns]

# %% [markdown]
# # Visualization

# %% [markdown]
# ## 1) Sex 변수를 기준으로 dimension reduction

# %%
features_sex = generated_imputed.drop("sex", axis=1) # independent variable 
target_sex = generated_imputed["sex"].values # target variable

# %%
features_sex.head()
# Out:
#    WBC  fschizoyn  Weight  fbipolyn  dep  flipyn    FBS  asth2  FEF25_75__exp  \
# 0  6.6        1.0    64.4       1.0  1.0     1.0   86.0    1.0     132.000000
# 1  4.2        1.0    69.6       1.0  1.0     1.0  110.0    1.0      66.000000
# 2  9.6        1.0    43.8       1.0  1.0     1.0  123.0    1.0      35.000000
# 3  8.2        1.0    66.3       1.0  1.0     1.0  120.0    1.0      93.520318
# 4  5.4        1.0    77.7       1.0  1.0     1.0  105.0    2.0      93.520318
#
#    htn  ...  lip  Calcium    PEF__exp   DBP    FVC__exp  jb_irelay  ces_dep  \
# 0  2.0  ...  1.0     10.8   80.000000  65.0   90.000000        1.0     25.0
# 1  1.0  ...  1.0      8.8  120.000000  82.0  100.000000        1.0      9.0
# 2  1.0  ...  1.0     10.3   55.000000  82.0  119.000000        1.0     19.0
# 3  1.0  ...  1.0     10.0  105.912085  79.0   98.557767        1.0     11.0
# 4  1.0  ...  1.0      9.2  105.912085  76.0   98.557767        1.0     20.0
#
#         PEF  alch   AST
# 0  6.200000   1.0  10.0
# 1  6.200000   1.0  12.0
# 2  8.400000   1.0  22.0
# 3  7.310154   1.0  25.0
# 4  7.310154   1.0  47.0
#
# [5 rows x 67 columns]

# %%
# t-SNE와 UMAP 알고리즘을 사용하여 2차원으로 차원 축소 
tsne_sex = TSNE(n_components=2).fit_transform(features_sex.values)
umap_sex = umap.UMAP().fit_transform(features_sex.values)

# %%
tsne_sex.shape
# Out:
# (101500, 2)

# %%
umap_sex.shape
# Out:
# (101500, 2)

# %%
sex_reduced = pd.DataFrame({"tsne_1" : tsne_sex[:, 0], "tsne_2" : tsne_sex[:, 1],
                            "umap_1" : umap_sex[:, 0], "umap_2" : umap_sex[:, 1],
                            "sex" : target_sex})

# %%
sex_reduced.head()
# Out:
#       tsne_1     tsne_2     umap_1     umap_2  sex
# 0  -1.770459  25.242903   5.990578  -1.784790  2.0
# 1 -16.670755 -30.625494  -7.600947   5.892385  2.0
# 2  11.074271  16.115391   8.137117  -1.652534  2.0
# 3 -21.680458 -26.507126  12.680542  14.448494  1.0
# 4   6.587345   0.393816   9.406620  -3.438395  1.0

# %%
sex_reduced.to_csv("sex_reduced.csv")

# %%
plt.figure(figsize=(15,10))
color_dict = dict({1 : "dodgerblue", 2 : "orange"})
g = sns.scatterplot(x="tsne_1", y="tsne_2", hue="sex", palette=color_dict, s=100, data=sex_reduced, legend=True)
plt.title("t-SNE")
plt.legend(title="Sex", labels=["Male", "Female"])
plt.show(g)

# %%
plt.figure(figsize=(15,10))
color_dict = dict({1 : "dodgerblue", 2 : "orange"})
g = sns.scatterplot(x="umap_1", y="umap_2", hue="sex", palette=color_dict, s=100, data=sex_reduced, legend=True)
plt.title("UMAP")
plt.legend(title="Sex", labels=["Male", "Female"])
plt.show(g)

# %% [markdown]
# ## 2) DM (당뇨병 진단 여부) 변수를 기준으로 dimension reduction

# %%
features_dm = generated_imputed.drop("dm", axis=1) # independent variable 
target_dm = generated_imputed["dm"].values # target variable

# %%
# t-SNE와 UMAP 알고리즘을 사용하여 2차원으로 차원 축소 
tsne_dm = TSNE(n_components=2).fit_transform(features_dm.values)
umap_dm = umap.UMAP().fit_transform(features_dm.values)
# Out:
# /home/yjjeong/anaconda3/envs/yj_ds_py38/lib/python3.8/site-packages/sklearn/manifold/_spectral_embedding.py:245: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %%
dm_reduced = pd.DataFrame({"tsne_1" : tsne_dm[:, 0], "tsne_2" : tsne_dm[:, 1],
                            "umap_1" : umap_dm[:, 0], "umap_2" : umap_dm[:, 1],
                            "dm" : target_dm})

# %%
dm_reduced.to_csv("dm_reduced.csv")

# %%
plt.figure(figsize=(15,10))
color_dict = dict({1 : "dodgerblue", 2 : "red"})
g = sns.scatterplot(x="tsne_1", y="tsne_2", hue="dm", palette=color_dict, s=100, data=dm_reduced, legend=True)
plt.title("t-SNE")
plt.legend(title="Diabetus Mellitus") # labels=["Negative", "Positive"]
plt.show(g)

# %%
plt.figure(figsize=(15,10))
color_dict = dict({1 : "dodgerblue", 2 : "red"})
g = sns.scatterplot(x="umap_1", y="umap_2", hue="dm", palette=color_dict, s=100, data=dm_reduced, legend=True)
plt.title("UMAP")
plt.legend(title="Diabetus Mellitus") # labels=["Negative", "Positive"]
plt.show(g)

# %% [markdown]
# # Single Cluster Analysis

# %% [markdown]
# - UMAP 결과에서 단독으로 큰 하나의 클러스터가 생성되어있어, 해당 클러스터를 자세히 보기 위함

# %% [markdown]
# ## 1) Sex 기준

# %% [markdown]
# - 위의 UMAP 결과에서 Main cluster 만 따로 확인해보기 위해 DBSCAN 클러스터링 알고리즘 사용

# %%
from sklearn.cluster import DBSCAN

# %%
sex_reduced.head()
# Out:
#       tsne_1     tsne_2     umap_1     umap_2  sex  DBSCAN_cluster
# 0  -1.770459  25.242903   5.990578  -1.784790  2.0               0
# 1 -16.670755 -30.625494  -7.600947   5.892385  2.0               1
# 2  11.074271  16.115391   8.137117  -1.652534  2.0               0
# 3 -21.680458 -26.507126  12.680542  14.448494  1.0               2
# 4   6.587345   0.393816   9.406620  -3.438395  1.0               0

# %%
cluster = DBSCAN(n_jobs = -1)

# %%
model_sex = cluster.fit(sex_reduced[["umap_1", "umap_2"]].values)
sex_reduced["DBSCAN_cluster"] = model_sex.labels_

# %%
# index of cluster with maximum points (main cluster)
sex_umap_main_cluster_idx = np.argmax(np.unique(model_sex.labels_, return_counts = True)[1])

# %%
sex_umap_main_cluster = sex_reduced.loc[sex_reduced["DBSCAN_cluster"] == sex_umap_main_cluster_idx]

# %%
sex_umap_main_cluster.head()
# Out:
#       tsne_1     tsne_2    umap_1    umap_2  sex  DBSCAN_cluster
# 0  -1.770459  25.242903  5.990578 -1.784790  2.0               0
# 2  11.074271  16.115391  8.137117 -1.652534  2.0               0
# 4   6.587345   0.393816  9.406620 -3.438395  1.0               0
# 6   0.062306   9.490357  7.093967 -2.408070  1.0               0
# 7   1.586003   1.865415  7.796623 -3.777759  1.0               0

# %%
plt.figure(figsize=(15,10))
color_dict = dict({1 : "dodgerblue", 2 : "orange"})
g = sns.scatterplot(x="umap_1", y="umap_2", hue="sex", palette=color_dict, s=100, data=sex_umap_main_cluster, legend=True)
plt.title("UMAP - Main Cluster")
plt.legend(title="Sex", labels=["Male", "Female"])
plt.show(g)

# %% [markdown]
# ## 2) DM 기준

# %%
model_dm = cluster.fit(dm_reduced[["umap_1", "umap_2"]].values)
dm_reduced["DBSCAN_cluster"] = model_dm.labels_

# %%
dm_reduced.head()
# Out:
#       tsne_1     tsne_2    umap_1     umap_2   dm  DBSCAN_cluster
# 0 -13.530903   0.056827  8.340916  -2.904307  1.0               0
# 1  44.294979   7.263562  7.909745  10.889163  1.0               1
# 2  -1.293858  -9.506601  6.167190  -2.691517  1.0               0
# 3 -21.264439  14.324333 -1.425374   4.674622  1.0               2
# 4  15.762550  -5.069273  5.491469  -0.726152  1.0               0

# %%
# index of cluster with maximum points (main cluster)
dm_umap_main_cluster_idx = np.argmax(np.unique(model_dm.labels_, return_counts = True)[1])

# %%
dm_umap_main_cluster = dm_reduced.loc[sex_reduced["DBSCAN_cluster"] == dm_umap_main_cluster_idx]

# %%
dm_umap_main_cluster.head()
# Out:
#       tsne_1    tsne_2    umap_1    umap_2   dm  DBSCAN_cluster
# 0 -13.530903  0.056827  8.340916 -2.904307  1.0               0
# 2  -1.293858 -9.506601  6.167190 -2.691517  1.0               0
# 4  15.762550 -5.069273  5.491469 -0.726152  1.0               0
# 6   2.787801  3.180573  7.632316 -2.097170  1.0               0
# 7   9.296308  3.778683  7.019457 -0.669539  1.0               0

# %%
plt.figure(figsize=(15,10))
color_dict = dict({1 : "dodgerblue", 2 : "red"})
g = sns.scatterplot(x="umap_1", y="umap_2", hue="dm", palette=color_dict, s=100, data=dm_umap_main_cluster, legend=True)
plt.title("UMAP - Main Cluster")
plt.legend(title="Diabetus Mellitus") # labels=["Negative", "Positive"]
plt.show(g)
